# %%
# Import library yang dibutuhkan
import os
import numpy as np
import librosa
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Input, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt

# Atur seed untuk reproduksibilitas awal
np.random.seed(42)
tf.random.set_seed(42)

# Sampling rate standar
SR = 22050
NUM_RUNS = 30 # Training masing-masing model 30 kali

# Fungsi untuk padding audio agar memiliki panjang yang sama
def pad_audio(y, target_length):
    """
    Padding dengan nol agar audio memiliki panjang `target_length`.
    """
    if len(y) < target_length:
        y = np.pad(y, (0, target_length - len(y)), mode='constant')
    else:
        y = y[:target_length]
    return y

# 1. Load Dataset
def load_audio_files(dataset_path, sr=SR, duration=None):
    """
    Memuat file audio dan label dari folder dataset.
    Asumsi: folder `dataset_path` memiliki subfolder untuk setiap kelas,
    masing-masing berisi file .wav.
    """
    audio_data = []
    labels = []
    class_names = []
    # Ambil daftar kelas (nama folder)
    for class_idx, class_name in enumerate(sorted(os.listdir(dataset_path))):
        class_folder = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_folder):
            continue
        class_names.append(class_name)
        # Iterasi file .wav dalam folder kelas
        for file_name in os.listdir(class_folder):
            if file_name.endswith('.wav'):
                file_path = os.path.join(class_folder, file_name)
                # Muat audio menggunakan librosa
                y, _ = librosa.load(file_path, sr=sr, duration=duration)
                audio_data.append(y)
                labels.append(class_idx)
    return audio_data, np.array(labels), class_names

# 2. Ekstraksi Fitur
def extract_mel_spectrogram(audio, sr=SR, n_mels=128, fmax=8000):
    """
    Menghitung mel-spectrogram log dari sinyal audio.
    """
    S = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=n_mels, fmax=fmax)
    S_db = librosa.power_to_db(S, ref=np.max)
    return S_db

def extract_mfcc(audio, sr=SR, n_mfcc=40):
    """
    Menghitung koefisien MFCC dari sinyal audio.
    """
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc)
    return mfcc

# 3. Membangun Model CNN untuk mel-spectrogram
def create_cnn_model_mel(input_shape, num_classes):
    """
    Membangun model CNN sederhana untuk klasifikasi berdasar mel-spectrogram.
    """
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2,2)),
        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Conv2D(128, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model

# 4. Membangun Model CNN untuk MFCC
def create_cnn_model_mfcc(input_shape, num_classes):
    """
    Membangun model CNN sederhana untuk klasifikasi berdasar MFCC.
    """
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2,2)),
        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Conv2D(128, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    return model

# Fungsi plotting
def plot_training_history(history, title="Model", run=None):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc)+1)

    plt.figure(figsize=(12,5))
    run_title = f" (Run {run})" if run else ""

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'{title} - Accuracy{run_title}')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'{title} - Loss{run_title}')

    plt.tight_layout()
    plt.show()

def resize_feature(feature, target_shape=(224, 224)):
    """
    Resize/padding fitur agar berukuran target_shape (224x224).
    """
    current_shape = feature.shape
    pad_height = max(0, target_shape[0] - current_shape[0])
    pad_width = max(0, target_shape[1] - current_shape[1])

    # Padding ke target shape
    padded = np.pad(feature,
                      pad_width=((0, pad_height), (0, pad_width)),
                      mode='constant', constant_values=0)

    # Jika lebih besar, crop
    resized = padded[:target_shape[0], :target_shape[1]]

    return resized

# ------------------------------------------------------------------------
# Main pipeline
# ------------------------------------------------------------------------
if __name__ == '__main__':
    # Path ke dataset
    dataset_path = 'Trimmed Audio Dataset'

    # 1) Muat data audio dan label 
    print("Memuat data audio...")
    audio_data, labels, class_names = load_audio_files(dataset_path, sr=SR)
    num_classes = len(class_names)

    # 1.a) Padding setiap audio ke panjang maksimum
    max_len = max(len(y) for y in audio_data)
    audio_data = [pad_audio(y, max_len) for y in audio_data]
    audio_data = np.array(audio_data)

    # Pra-pemrosesan fitur 
    print("Mengekstrak fitur Mel-Spectrogram dan MFCC...")
    X_mel_full = []
    for y in audio_data:
        S_db = extract_mel_spectrogram(y, sr=SR, n_mels=128)
        resized_feature = resize_feature(S_db, target_shape=(224, 224))
        X_mel_full.append(resized_feature[..., np.newaxis])
    X_mel_full = np.array(X_mel_full)

    X_mfcc_full = []
    for y in audio_data:
        mfcc = extract_mfcc(y, sr=SR, n_mfcc=40)
        resized_feature = resize_feature(mfcc, target_shape=(224, 224))
        X_mfcc_full.append(resized_feature[..., np.newaxis])
    X_mfcc_full = np.array(X_mfcc_full)

    # Simpan metrik untuk semua model dari semua run
    all_run_results = []
    all_run_cms = []

    # Definisikan callbacks
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=10, # sedikit lebih sabar
        restore_best_weights=True,
        verbose=1
    )
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
    callbacks = [early_stop, reduce_lr]

    EPOCHS = 150
    BATCH_SIZE = 32

    # Loop untuk melatih dan mengevaluasi model sebanyak NUM_RUNS
    for run in range(1, NUM_RUNS + 1):
        print(f"\n{'='*30} RUN {run}/{NUM_RUNS} {'='*30}")

        # 1.b) Tentukan pembagian train-test dengan stratifikasi label untuk setiap run
        # Menggunakan random_state berbeda agar split bervariasi tapi tetap reproduktif
        indices = np.arange(len(labels))
        train_idx, test_idx = train_test_split(indices, test_size=0.2, stratify=labels, random_state=42 + run)
        
        y_train, y_test = labels[train_idx], labels[test_idx]

        # ========================================================================
        # Model 1: CNN dengan fitur mel-spectrogram
        # ========================================================================
        print(f"\n[RUN {run} - Model 1] CNN dengan fitur Mel-Spectrogram")
        
        # Bagi train/test
        X_train_mel, X_test_mel = X_mel_full[train_idx], X_mel_full[test_idx]
        
        # Bangun, compile, dan latih model (harus di dalam loop untuk reset weights)
        input_shape_mel = X_train_mel.shape[1:]
        model_mel = create_cnn_model_mel(input_shape_mel, num_classes)
        model_mel.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        
        print(f"Training Mel-CNN model for run {run}...")
        history_mel = model_mel.fit(
            X_train_mel, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test_mel, y_test),
            callbacks=callbacks,
            verbose=0 # Set ke 0 agar tidak terlalu ramai, atau 2 untuk ringkasan per epoch
        )
        
        # Tampilkan grafik untuk run ini
        plot_training_history(history_mel, title="CNN Mel-Spectrogram", run=run)
        
        # Evaluasi
        print(f"Evaluating Mel-CNN model for run {run}...")
        y_pred_mel = np.argmax(model_mel.predict(X_test_mel), axis=1)
        
        # Kumpulkan metrik performa
        run_results_mel = {
            "Run": run,
            "Model": "CNN Mel",
            "Accuracy": accuracy_score(y_test, y_pred_mel),
            "Precision": precision_score(y_test, y_pred_mel, average='macro', zero_division=0),
            "Recall": recall_score(y_test, y_pred_mel, average='macro', zero_division=0),
            "F1": f1_score(y_test, y_pred_mel, average='macro', zero_division=0),
            "Train Accuracy": history_mel.history['accuracy'][-1],
            "Train Loss": history_mel.history['loss'][-1],
            "Val Accuracy": history_mel.history['val_accuracy'][-1],
            "Val Loss": history_mel.history['val_loss'][-1]
        }
        all_run_results.append(run_results_mel)
        
        # Kumpulkan confusion matrix
        cm_mel = confusion_matrix(y_test, y_pred_mel)
        for true_idx, row in enumerate(cm_mel):
            for pred_idx, count in enumerate(row):
                all_run_cms.append({
                    'Run': run,
                    'Model': 'CNN Mel',
                    'True_Label': class_names[true_idx],
                    'Predicted_Label': class_names[pred_idx],
                    'Count': count
                })

        print(f"Classification Report (Mel-CNN, Run {run}):")
        print(classification_report(y_test, y_pred_mel, target_names=class_names, zero_division=0))

        # ========================================================================
        # Model 2: CNN dengan fitur MFCC
        # ========================================================================
        print(f"\n[RUN {run} - Model 2] CNN dengan fitur MFCC")
        X_train_mfcc, X_test_mfcc = X_mfcc_full[train_idx], X_mfcc_full[test_idx]
        
        model_mfcc = create_cnn_model_mfcc(X_train_mfcc.shape[1:], num_classes)
        model_mfcc.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        
        print(f"Training MFCC-CNN model for run {run}...")
        history_mfcc = model_mfcc.fit(
            X_train_mfcc, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test_mfcc, y_test),
            callbacks=callbacks,
            verbose=0
        )
        
        # Tampilkan grafik untuk run ini
        plot_training_history(history_mfcc, title="CNN MFCC", run=run)
        
        # Evaluasi
        print(f"Evaluating MFCC-CNN model for run {run}...")
        y_pred_mfcc = np.argmax(model_mfcc.predict(X_test_mfcc), axis=1)

        # Kumpulkan metrik performa
        run_results_mfcc = {
            "Run": run,
            "Model": "CNN MFCC",
            "Accuracy": accuracy_score(y_test, y_pred_mfcc),
            "Precision": precision_score(y_test, y_pred_mfcc, average='macro', zero_division=0),
            "Recall": recall_score(y_test, y_pred_mfcc, average='macro', zero_division=0),
            "F1": f1_score(y_test, y_pred_mfcc, average='macro', zero_division=0),
            "Train Accuracy": history_mfcc.history['accuracy'][-1],
            "Train Loss": history_mfcc.history['loss'][-1],
            "Val Accuracy": history_mfcc.history['val_accuracy'][-1],
            "Val Loss": history_mfcc.history['val_loss'][-1]
        }
        all_run_results.append(run_results_mfcc)
        
        # Kumpulkan confusion matrix
        cm_mfcc = confusion_matrix(y_test, y_pred_mfcc)
        for true_idx, row in enumerate(cm_mfcc):
            for pred_idx, count in enumerate(row):
                all_run_cms.append({
                    'Run': run,
                    'Model': 'CNN MFCC',
                    'True_Label': class_names[true_idx],
                    'Predicted_Label': class_names[pred_idx],
                    'Count': count
                })
        
        print(f"Classification Report (MFCC-CNN, Run {run}):")
        print(classification_report(y_test, y_pred_mfcc, target_names=class_names, zero_division=0))


    # ========================================================================
    # Selesai semua run, simpan hasil kompilasi
    # ========================================================================
    print("\n\n" + "="*25 + " SEMUA RUN SELESAI " + "="*25)

    # Simpan performa ke CSV
    performance_df = pd.DataFrame(all_run_results)
    performance_csv_path = 'CNN_Kombinasi2_all_run_performance.csv'
    performance_df.to_csv(performance_csv_path, index=False)
    print(f"\nPerforma dari {NUM_RUNS} run disimpan ke: {performance_csv_path}")
    print("Ringkasan Performa (rata-rata dari semua run):")
    print(performance_df.groupby('Model')[['Accuracy', 'Precision', 'Recall', 'F1']].mean())

    # Simpan confusion matrix semua run ke file CSV terpisah
    cm_df = pd.DataFrame(all_run_cms)
    cm_csv_path = 'CNN_Kombinasi2_all_run_confusion_matrices.csv'
    cm_df.to_csv(cm_csv_path, index=False)
    print(f"\nConfusion matrices dari semua run disimpan ke: {cm_csv_path}")
    
    # ========================================================================
    # Simpan model dari RUN TERAKHIR
    # ========================================================================
    
    # Pastikan folder 'fix_Model/CNN_Kombinasi1' ada
    model_save_path = 'fix_Model/CNN_Kombinasi2'
    os.makedirs(model_save_path, exist_ok=True)
    
    # Simpan dalam format native Keras (.keras)
    model_mel.save(os.path.join(model_save_path, 'Mel_final_run.keras'))
    model_mfcc.save(os.path.join(model_save_path, 'MFCC_final_run.keras'))
    print(f"\nModel dari run terakhir ({NUM_RUNS}) disimpan di folder: {model_save_path}")
# Out:
# WARNING:tensorflow:From c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Memuat data audio...
# Mengekstrak fitur Mel-Spectrogram dan MFCC...
#
# ============================== RUN 1/30 ==============================
#
# [RUN 1 - Model 1] CNN dengan fitur Mel-Spectrogram
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Mel-CNN model for run 1...
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Evaluating Mel-CNN model for run 1...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step
# Classification Report (Mel-CNN, Run 1):
#               precision    recall  f1-score   support
#
#       Cendet       0.88      0.79      0.83        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.93      0.93      0.93        30
#     Perkutut       0.88      0.94      0.91        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.93       112
#    macro avg       0.93      0.93      0.93       112
# weighted avg       0.93      0.93      0.93       112
#
#
# [RUN 1 - Model 2] CNN dengan fitur MFCC
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training MFCC-CNN model for run 1...
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Evaluating MFCC-CNN model for run 1...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
# Classification Report (MFCC-CNN, Run 1):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 2/30 ==============================
#
# [RUN 2 - Model 1] CNN dengan fitur Mel-Spectrogram
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Mel-CNN model for run 2...
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating Mel-CNN model for run 2...
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000012DBC0223B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000012DBC0223B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step
# Classification Report (Mel-CNN, Run 2):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.84      0.89        19
#       Gereja       0.79      0.85      0.81        13
#     Kutilang       0.86      1.00      0.92        30
#     Perkutut       0.87      0.81      0.84        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.89      0.94        19
#
#     accuracy                           0.90       112
#    macro avg       0.91      0.89      0.90       112
# weighted avg       0.91      0.90      0.90       112
#
#
# [RUN 2 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 2...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Evaluating MFCC-CNN model for run 2...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step
# Classification Report (MFCC-CNN, Run 2):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# ============================== RUN 3/30 ==============================
#
# [RUN 3 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 3...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating Mel-CNN model for run 3...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step
# Classification Report (Mel-CNN, Run 3):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       0.92      0.85      0.88        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.93      0.87      0.90        15
#     Trucukan       0.86      1.00      0.93        19
#
#     accuracy                           0.93       112
#    macro avg       0.93      0.92      0.92       112
# weighted avg       0.93      0.93      0.93       112
#
#
# [RUN 3 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 3...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Evaluating MFCC-CNN model for run 3...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step
# Classification Report (MFCC-CNN, Run 3):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      0.85      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 4/30 ==============================
#
# [RUN 4 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 4...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating Mel-CNN model for run 4...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step
# Classification Report (Mel-CNN, Run 4):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       0.85      0.85      0.85        13
#     Kutilang       0.85      0.93      0.89        30
#     Perkutut       0.88      0.94      0.91        16
#      Tekukur       0.87      0.87      0.87        15
#     Trucukan       1.00      0.84      0.91        19
#
#     accuracy                           0.89       112
#    macro avg       0.90      0.89      0.89       112
# weighted avg       0.90      0.89      0.89       112
#
#
# [RUN 4 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 4...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Evaluating MFCC-CNN model for run 4...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# Classification Report (MFCC-CNN, Run 4):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.98       112
#    macro avg       0.99      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# ============================== RUN 5/30 ==============================
#
# [RUN 5 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 5...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Evaluating Mel-CNN model for run 5...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# Classification Report (Mel-CNN, Run 5):
#               precision    recall  f1-score   support
#
#       Cendet       0.83      1.00      0.90        19
#       Gereja       0.80      0.62      0.70        13
#     Kutilang       0.90      0.93      0.92        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.92      0.80      0.86        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.89       112
#    macro avg       0.89      0.87      0.88       112
# weighted avg       0.89      0.89      0.89       112
#
#
# [RUN 5 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 5...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Evaluating MFCC-CNN model for run 5...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# Classification Report (MFCC-CNN, Run 5):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.98       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# ============================== RUN 6/30 ==============================
#
# [RUN 6 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 6...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Evaluating Mel-CNN model for run 6...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step
# Classification Report (Mel-CNN, Run 6):
#               precision    recall  f1-score   support
#
#       Cendet       0.75      0.79      0.77        19
#       Gereja       0.58      0.54      0.56        13
#     Kutilang       0.90      0.90      0.90        30
#     Perkutut       0.94      1.00      0.97        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.85      0.89      0.87        19
#
#     accuracy                           0.85       112
#    macro avg       0.84      0.83      0.83       112
# weighted avg       0.85      0.85      0.85       112
#
#
# [RUN 6 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 6...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 47.
# Evaluating MFCC-CNN model for run 6...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step
# Classification Report (MFCC-CNN, Run 6):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# ============================== RUN 7/30 ==============================
#
# [RUN 7 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 7...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Evaluating Mel-CNN model for run 7...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step
# Classification Report (Mel-CNN, Run 7):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.79      0.86        19
#       Gereja       0.69      0.69      0.69        13
#     Kutilang       0.83      0.97      0.89        30
#     Perkutut       0.93      0.88      0.90        16
#      Tekukur       0.82      0.93      0.88        15
#     Trucukan       1.00      0.84      0.91        19
#
#     accuracy                           0.87       112
#    macro avg       0.87      0.85      0.86       112
# weighted avg       0.87      0.87      0.87       112
#
#
# [RUN 7 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 7...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Evaluating MFCC-CNN model for run 7...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step
# Classification Report (MFCC-CNN, Run 7):
#               precision    recall  f1-score   support
#
#       Cendet       0.90      0.95      0.92        19
#       Gereja       0.80      0.92      0.86        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       0.88      0.94      0.91        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.94       112
#    macro avg       0.93      0.93      0.93       112
# weighted avg       0.94      0.94      0.94       112
#
#
# ============================== RUN 8/30 ==============================
#
# [RUN 8 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 8...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Evaluating Mel-CNN model for run 8...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (Mel-CNN, Run 8):
#               precision    recall  f1-score   support
#
#       Cendet       0.89      0.89      0.89        19
#       Gereja       0.91      0.77      0.83        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.88      0.93      0.90        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.92       112
#    macro avg       0.92      0.91      0.91       112
# weighted avg       0.92      0.92      0.92       112
#
#
# [RUN 8 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 8...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
# Evaluating MFCC-CNN model for run 8...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (MFCC-CNN, Run 8):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 9/30 ==============================
#
# [RUN 9 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 9...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Evaluating Mel-CNN model for run 9...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step
# Classification Report (Mel-CNN, Run 9):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.83      1.00      0.91        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.84      0.91        19
#
#     accuracy                           0.94       112
#    macro avg       0.96      0.93      0.94       112
# weighted avg       0.95      0.94      0.94       112
#
#
# [RUN 9 - Model 2] CNN dengan fitur MFCC
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training MFCC-CNN model for run 9...
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Evaluating MFCC-CNN model for run 9...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (MFCC-CNN, Run 9):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.91      1.00      0.95        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.97       112
# weighted avg       0.97      0.96      0.96       112
#
#
# ============================== RUN 10/30 ==============================
#
# [RUN 10 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 10...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Evaluating Mel-CNN model for run 10...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# Classification Report (Mel-CNN, Run 10):
#               precision    recall  f1-score   support
#
#       Cendet       0.90      1.00      0.95        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.88      0.93      0.90        30
#     Perkutut       1.00      0.81      0.90        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.94       112
#    macro avg       0.95      0.93      0.94       112
# weighted avg       0.94      0.94      0.94       112
#
#
# [RUN 10 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 10...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating MFCC-CNN model for run 10...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step
# Classification Report (MFCC-CNN, Run 10):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 11/30 ==============================
#
# [RUN 11 - Model 1] CNN dengan fitur Mel-Spectrogram
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Mel-CNN model for run 11...
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Evaluating Mel-CNN model for run 11...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step
# Classification Report (Mel-CNN, Run 11):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.79      0.86        19
#       Gereja       0.81      1.00      0.90        13
#     Kutilang       0.91      0.97      0.94        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.92       112
#    macro avg       0.92      0.92      0.92       112
# weighted avg       0.92      0.92      0.92       112
#
#
# [RUN 11 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 11...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Evaluating MFCC-CNN model for run 11...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# Classification Report (MFCC-CNN, Run 11):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 12/30 ==============================
#
# [RUN 12 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 12...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Evaluating Mel-CNN model for run 12...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
# Classification Report (Mel-CNN, Run 12):
#               precision    recall  f1-score   support
#
#       Cendet       0.72      0.68      0.70        19
#       Gereja       0.88      0.54      0.67        13
#     Kutilang       0.90      0.93      0.92        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       0.79      1.00      0.88        19
#
#     accuracy                           0.86       112
#    macro avg       0.86      0.84      0.84       112
# weighted avg       0.86      0.86      0.85       112
#
#
# [RUN 12 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 12...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Evaluating MFCC-CNN model for run 12...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step
# Classification Report (MFCC-CNN, Run 12):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# ============================== RUN 13/30 ==============================
#
# [RUN 13 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 13...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Evaluating Mel-CNN model for run 13...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
# Classification Report (Mel-CNN, Run 13):
#               precision    recall  f1-score   support
#
#       Cendet       0.78      0.95      0.86        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.89      0.80      0.84        30
#     Perkutut       0.89      1.00      0.94        16
#      Tekukur       1.00      0.80      0.89        15
#     Trucukan       1.00      0.89      0.94        19
#
#     accuracy                           0.89       112
#    macro avg       0.90      0.91      0.90       112
# weighted avg       0.90      0.89      0.89       112
#
#
# [RUN 13 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 13...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Evaluating MFCC-CNN model for run 13...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (MFCC-CNN, Run 13):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 14/30 ==============================
#
# [RUN 14 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 14...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Evaluating Mel-CNN model for run 14...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step
# Classification Report (Mel-CNN, Run 14):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 14 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 14...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Evaluating MFCC-CNN model for run 14...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (MFCC-CNN, Run 14):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 15/30 ==============================
#
# [RUN 15 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 15...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Evaluating Mel-CNN model for run 15...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
# Classification Report (Mel-CNN, Run 15):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.93      0.97        30
#     Perkutut       0.93      0.88      0.90        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.97      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 15 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 15...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# Evaluating MFCC-CNN model for run 15...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
# Classification Report (MFCC-CNN, Run 15):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 16/30 ==============================
#
# [RUN 16 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 16...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Evaluating Mel-CNN model for run 16...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step
# Classification Report (Mel-CNN, Run 16):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.95       112
# weighted avg       0.96      0.96      0.96       112
#
#
# [RUN 16 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 16...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Evaluating MFCC-CNN model for run 16...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# Classification Report (MFCC-CNN, Run 16):
#               precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 17/30 ==============================
#
# [RUN 17 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 17...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...
# Evaluating MFCC-CNN model for run 25...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
# Classification Report (MFCC-CNN, Run 25):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.88      1.00      0.94        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.95      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# ============================== RUN 26/30 ==============================
#
# [RUN 26 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 26...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Evaluating Mel-CNN model for run 26...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# Classification Report (Mel-CNN, Run 26):
#               precision    recall  f1-score   support
#
#       Cendet       0.88      0.79      0.83        19
#       Gereja       0.68      1.00      0.81        13
#     Kutilang       0.93      0.87      0.90        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       0.92      0.80      0.86        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.88       112
#    macro avg       0.88      0.89      0.88       112
# weighted avg       0.90      0.88      0.89       112
#
#
# [RUN 26 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 26...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 150.
# Evaluating MFCC-CNN model for run 26...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step
# Classification Report (MFCC-CNN, Run 26):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# ============================== RUN 27/30 ==============================
#
# [RUN 27 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 27...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Evaluating Mel-CNN model for run 27...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# Classification Report (Mel-CNN, Run 27):
#               precision    recall  f1-score   support
#
#       Cendet       0.90      0.95      0.92        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.88      0.93      0.90        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.89      0.94        19
#
#     accuracy                           0.94       112
#    macro avg       0.95      0.94      0.94       112
# weighted avg       0.94      0.94      0.94       112
#
#
# [RUN 27 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 27...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 150.
# Evaluating MFCC-CNN model for run 27...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# Classification Report (MFCC-CNN, Run 27):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# ============================== RUN 28/30 ==============================
#
# [RUN 28 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 28...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Evaluating Mel-CNN model for run 28...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step
# Classification Report (Mel-CNN, Run 28):
#               precision    recall  f1-score   support
#
#       Cendet       0.90      1.00      0.95        19
#       Gereja       0.89      0.62      0.73        13
#     Kutilang       0.78      0.97      0.87        30
#     Perkutut       0.79      0.69      0.73        16
#      Tekukur       0.87      0.87      0.87        15
#     Trucukan       0.88      0.74      0.80        19
#
#     accuracy                           0.84       112
#    macro avg       0.85      0.81      0.82       112
# weighted avg       0.84      0.84      0.83       112
#
#
# [RUN 28 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 28...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating MFCC-CNN model for run 28...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step
# Classification Report (MFCC-CNN, Run 28):
#               precision    recall  f1-score   support
#
#       Cendet       0.86      1.00      0.93        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# ============================== RUN 29/30 ==============================
#
# [RUN 29 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 29...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Evaluating Mel-CNN model for run 29...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step
# Classification Report (Mel-CNN, Run 29):
#               precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.87      0.90      0.89        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.93       112
#    macro avg       0.94      0.93      0.94       112
# weighted avg       0.93      0.93      0.93       112
#
#
# [RUN 29 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 29...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Evaluating MFCC-CNN model for run 29...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step
# Classification Report (MFCC-CNN, Run 29):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 30/30 ==============================
#
# [RUN 30 - Model 1] CNN dengan fitur Mel-Spectrogram
# Training Mel-CNN model for run 30...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Evaluating Mel-CNN model for run 30...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step
# Classification Report (Mel-CNN, Run 30):
#               precision    recall  f1-score   support
#
#       Cendet       1.00      0.84      0.91        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.88      0.93      0.90        30
#     Perkutut       0.94      1.00      0.97        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.85      0.89      0.87        19
#
#     accuracy                           0.92       112
#    macro avg       0.93      0.92      0.93       112
# weighted avg       0.92      0.92      0.92       112
#
#
# [RUN 30 - Model 2] CNN dengan fitur MFCC
# Training MFCC-CNN model for run 30...
# c:\Users\Daniswara Aditya P\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Evaluating MFCC-CNN model for run 30...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step
# Classification Report (MFCC-CNN, Run 30):
#               precision    recall  f1-score   support
#
#       Cendet       0.86      0.95      0.90        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       0.93      0.88      0.90        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.95       112
#    macro avg       0.95      0.94      0.94       112
# weighted avg       0.95      0.95      0.95       112
#
#
#
# ========================= SEMUA RUN SELESAI =========================
#
# Performa dari 30 run disimpan ke: CNN_Kombinasi2_all_run_performance.csv
# Ringkasan Performa (rata-rata dari semua run):
#           Accuracy  Precision    Recall        F1
# Model
# CNN MFCC  0.979762   0.981919  0.977428  0.979014
# CNN Mel   0.911607   0.917915  0.908001  0.910245
#
# Confusion matrices dari semua run disimpan ke: CNN_Kombinasi2_all_run_confusion_matrices.csv
#
# Model dari run terakhir (30) disimpan di folder: fix_Model/CNN_Kombinasi2
