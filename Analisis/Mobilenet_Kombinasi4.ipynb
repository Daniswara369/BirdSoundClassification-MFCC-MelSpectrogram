# %%
# Import library yang dibutuhkan
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import pandas as pd
import matplotlib.pyplot as plt

# Atur seed untuk reproduksibilitas awal
np.random.seed(42)
tf.random.set_seed(42)

# Konfigurasi
SR = 22050
NUM_RUNS = 29 #

# --- Fungsi Helper (Sama seperti sebelumnya) ---

def pad_audio(y, target_length):
    if len(y) < target_length:
        y = np.pad(y, (0, target_length - len(y)), mode='constant')
    else:
        y = y[:target_length]
    return y

def load_audio_files(dataset_path, sr=SR):
    audio_data = []
    labels = []
    class_names = []
    for class_idx, class_name in enumerate(sorted(os.listdir(dataset_path))):
        class_folder = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_folder):
            continue
        class_names.append(class_name)
        for file_name in os.listdir(class_folder):
            if file_name.endswith('.wav'):
                file_path = os.path.join(class_folder, file_name)
                y, _ = librosa.load(file_path, sr=sr)
                audio_data.append(y)
                labels.append(class_idx)
    return audio_data, np.array(labels), class_names

def extract_mel_spectrogram(audio, sr=SR, n_mels=128, fmax=8000):
    S = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=n_mels, fmax=fmax)
    S_db = librosa.power_to_db(S, ref=np.max)
    return S_db

def extract_mfcc(audio, sr=SR, n_mfcc=40):
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc)
    return mfcc

def resize_feature(feature, target_shape=(224, 224)):
    current_shape = feature.shape
    # Untuk resize, kita bisa menggunakan tf.image.resize yang lebih efisien
    # Tambahkan dimensi channel sementara
    feature_with_channel = feature[..., np.newaxis]
    resized = tf.image.resize(feature_with_channel, target_shape).numpy()
    return np.squeeze(resized, axis=-1)

def plot_training_history(history, title="Model", run=None):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc)+1)

    plt.figure(figsize=(12, 5))
    run_title = f" (Run {run})" if run else ""
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'{title} - Accuracy{run_title}')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'{title} - Loss{run_title}')

    plt.tight_layout()
    plt.show()

# --- Fungsi Pembangunan Model ---

def create_transfer_mobilenet(input_shape, num_classes):
    """
    Membangun model klasifikasi dengan MobileNet (pra-terlatih) dari Keras Applications.
    """
    # Menggunakan `weights='imagenet'` secara otomatis akan mengunduh bobot yang sesuai.
    base_model = tf.keras.applications.MobileNet(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = True
    
    # Membangun model baru di atas base_model
    inputs = Input(shape=input_shape)
    # MobileNet mengharapkan input ternormalisasi. Kita bisa menggunakan lapisan normalisasi
    # atau membiarkannya belajar dari data float yang ada. Untuk konsistensi, kita biarkan saja.
    x = base_model(inputs, training=True)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    return model

# ------------------------------------------------------------------------
# Main pipeline
# ------------------------------------------------------------------------
if __name__ == '__main__':
    dataset_path = '/kaggle/input/trimmedaudio/Trimmed Audio Dataset'
    
    # 1) Muat dan pra-pemrosesan data (hanya sekali)
    print("Memuat data audio...")
    audio_data, labels, class_names = load_audio_files(dataset_path, sr=SR)
    num_classes = len(class_names)
    
    max_len = max(len(y) for y in audio_data)
    audio_data = [pad_audio(y, max_len) for y in audio_data]

    # Ekstraksi fitur dan persiapan untuk model (hanya sekali)
    print("Mengekstrak fitur dan mempersiapkannya untuk MobileNet...")
    X_mel_full = []
    for y in audio_data:
        S_db = extract_mel_spectrogram(y, sr=SR)
        resized_feature = resize_feature(S_db, target_shape=(224, 224))
        # Ulangi channel untuk membuat input 3-channel
        rgb_feature = np.repeat(resized_feature[..., np.newaxis], 3, axis=-1)
        X_mel_full.append(rgb_feature)
    X_mel_full = np.array(X_mel_full)

    X_mfcc_full = []
    for y in audio_data:
        mfcc = extract_mfcc(y, sr=SR)
        resized_feature = resize_feature(mfcc, target_shape=(224, 224))
        rgb_feature = np.repeat(resized_feature[..., np.newaxis], 3, axis=-1)
        X_mfcc_full.append(rgb_feature)
    X_mfcc_full = np.array(X_mfcc_full)
    
    print(f"Bentuk data Mel-Spectrogram: {X_mel_full.shape}")
    print(f"Bentuk data MFCC: {X_mfcc_full.shape}")

    # Inisialisasi list untuk menyimpan hasil dari semua run
    all_run_results = []
    all_run_cms = []

    # Definisikan callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)
    callbacks = [early_stop, reduce_lr]

    EPOCHS = 120
    BATCH_SIZE = 32

    # Loop untuk melatih dan mengevaluasi model sebanyak NUM_RUNS
    for run in range(1, NUM_RUNS + 1):
        print(f"\n{'='*30} RUN {run}/{NUM_RUNS} {'='*30}")

        indices = np.arange(len(labels))
        train_idx, test_idx = train_test_split(indices, test_size=0.2, stratify=labels, random_state=42 + run)
        y_train, y_test = labels[train_idx], labels[test_idx]
        
        # --- Model 1: MobileNet dengan Mel-Spectrogram ---
        print(f"\n[RUN {run} - Model 1] Transfer Learning MobileNet (Mel-spectrogram)")
        X_train_mel, X_test_mel = X_mel_full[train_idx], X_mel_full[test_idx]
        
        model_melnet = create_transfer_mobilenet(X_train_mel.shape[1:], num_classes)
        model_melnet.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        history_melnet = model_melnet.fit(
            X_train_mel, y_train,
            epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test_mel, y_test),
            callbacks=callbacks, verbose=0
        )
        
        plot_training_history(history_melnet, title="MobileNet Mel-Spectrogram", run=run)
        
        y_pred_melnet = np.argmax(model_melnet.predict(X_test_mel), axis=1)
        
        # Kumpulkan Metrik Performa
        all_run_results.append({
            "Run": run, "Model": "MobileNet (Mel)",
            "Accuracy": accuracy_score(y_test, y_pred_melnet),
            "Precision": precision_score(y_test, y_pred_melnet, average='macro', zero_division=0),
            "Recall": recall_score(y_test, y_pred_melnet, average='macro', zero_division=0),
            "F1": f1_score(y_test, y_pred_melnet, average='macro', zero_division=0),
            "Train Accuracy": history_melnet.history['accuracy'][-1], "Train Loss": history_melnet.history['loss'][-1],
            "Val Accuracy": history_melnet.history['val_accuracy'][-1], "Val Loss": history_melnet.history['val_loss'][-1]
        })
        
        # Kumpulkan Confusion Matrix
        cm_melnet = confusion_matrix(y_test, y_pred_melnet)
        for true_idx, row in enumerate(cm_melnet):
            for pred_idx, count in enumerate(row):
                all_run_cms.append({'Run': run, 'Model': 'MobileNet (Mel)', 'True_Label': class_names[true_idx], 'Predicted_Label': class_names[pred_idx], 'Count': count})
        
        print(f"Classification Report (MobileNet-Mel, Run {run}):\n", classification_report(y_test, y_pred_melnet, target_names=class_names, zero_division=0))

        # --- Model 2: MobileNet dengan MFCC ---
        print(f"\n[RUN {run} - Model 2] Transfer Learning MobileNet (MFCC)")
        X_train_mfcc, X_test_mfcc = X_mfcc_full[train_idx], X_mfcc_full[test_idx]
        
        model_mfccnet = create_transfer_mobilenet(X_train_mfcc.shape[1:], num_classes)
        model_mfccnet.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        
        history_mfccnet = model_mfccnet.fit(
            X_train_mfcc, y_train,
            epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test_mfcc, y_test),
            callbacks=callbacks, verbose=0
        )

        plot_training_history(history_mfccnet, title="MobileNet MFCC", run=run)

        y_pred_mfccnet = np.argmax(model_mfccnet.predict(X_test_mfcc), axis=1)
        
        # Kumpulkan Metrik Performa
        all_run_results.append({
            "Run": run, "Model": "MobileNet (MFCC)",
            "Accuracy": accuracy_score(y_test, y_pred_mfccnet),
            "Precision": precision_score(y_test, y_pred_mfccnet, average='macro', zero_division=0),
            "Recall": recall_score(y_test, y_pred_mfccnet, average='macro', zero_division=0),
            "F1": f1_score(y_test, y_pred_mfccnet, average='macro', zero_division=0),
            "Train Accuracy": history_mfccnet.history['accuracy'][-1], "Train Loss": history_mfccnet.history['loss'][-1],
            "Val Accuracy": history_mfccnet.history['val_accuracy'][-1], "Val Loss": history_mfccnet.history['val_loss'][-1]
        })

        # Kumpulkan Confusion Matrix
        cm_mfccnet = confusion_matrix(y_test, y_pred_mfccnet)
        for true_idx, row in enumerate(cm_mfccnet):
            for pred_idx, count in enumerate(row):
                all_run_cms.append({'Run': run, 'Model': 'MobileNet (MFCC)', 'True_Label': class_names[true_idx], 'Predicted_Label': class_names[pred_idx], 'Count': count})

        print(f"Classification Report (MobileNet-MFCC, Run {run}):\n", classification_report(y_test, y_pred_mfccnet, target_names=class_names, zero_division=0))

    # ========================================================================
    # Selesai semua run, simpan hasil kompilasi
    # ========================================================================
    print("\n\n" + "="*25 + " SEMUA RUN SELESAI " + "="*25)

    # Simpan performa ke CSV
    performance_df = pd.DataFrame(all_run_results)
    performance_csv_path = 'mobilenet_kombinasi4_all_performance.csv'
    performance_df.to_csv(performance_csv_path, index=False)
    print(f"\nPerforma dari {NUM_RUNS} run disimpan ke: {performance_csv_path}")
    print("Ringkasan Performa (rata-rata dari semua run):")
    print(performance_df.groupby('Model')[['Accuracy', 'Precision', 'Recall', 'F1']].mean())

    # impan confusion matrix semua run ke file CSV terpisah
    cm_df = pd.DataFrame(all_run_cms)
    cm_csv_path = 'mobilenet_kombinasi4_all_confusion_matrices.csv'
    cm_df.to_csv(cm_csv_path, index=False)
    print(f"\nConfusion matrices dari semua run disimpan ke: {cm_csv_path}")
    
    # ========================================================================
    # Simpan model dari RUN TERAKHIR
    # ========================================================================
    
    
    model_melnet.save('MobileNet4_Mel_final_run.keras')
    model_mfccnet.save('MobileNet4_MFCC_final_run.keras')
    # print(f"\nModel dari run terakhir ({NUM_RUNS}) disimpan di folder: {model_save_path}")
# Out:
# 2025-06-29 03:15:21.194697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751166921.403986      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751166921.465376      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Memuat data audio...
# Mengekstrak fitur dan mempersiapkannya untuk MobileNet...
# I0000 00:00:1751166953.823529      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Bentuk data Mel-Spectrogram: (559, 224, 224, 3)
# Bentuk data MFCC: (559, 224, 224, 3)
#
# ============================== RUN 1/30 ==============================
#
# [RUN 1 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751166988.108037     104 service.cc:148] XLA service 0x7d56500a3f80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751166988.108766     104 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1751166989.911568     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1751166993.959791     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751166994.159507     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1751166999.899357     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# E0000 00:00:1751167005.104075     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1751167005.304710     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 633ms/step
# Classification Report (MobileNet-Mel, Run 1):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# [RUN 1 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 117.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 809ms/step
# Classification Report (MobileNet-MFCC, Run 1):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.84      0.91        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.83      1.00      0.90        19
#
#     accuracy                           0.95       112
#    macro avg       0.96      0.95      0.95       112
# weighted avg       0.95      0.95      0.95       112
#
#
# ============================== RUN 2/30 ==============================
#
# [RUN 2 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 585ms/step
# Classification Report (MobileNet-Mel, Run 2):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# [RUN 2 - Model 2] Transfer Learning MobileNet (MFCC)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 587ms/step
# Classification Report (MobileNet-MFCC, Run 2):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 3/30 ==============================
#
# [RUN 3 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 604ms/step
# Classification Report (MobileNet-Mel, Run 3):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.81      0.90        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 3 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 582ms/step
# Classification Report (MobileNet-MFCC, Run 3):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.84      0.91        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.91      0.97      0.94        30
#     Perkutut       1.00      0.81      0.90        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.86      1.00      0.93        19
#
#     accuracy                           0.94       112
#    macro avg       0.95      0.94      0.94       112
# weighted avg       0.94      0.94      0.94       112
#
#
# ============================== RUN 4/30 ==============================
#
# [RUN 4 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 570ms/step
# Classification Report (MobileNet-Mel, Run 4):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 4 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 119.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 599ms/step
# Classification Report (MobileNet-MFCC, Run 4):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 5/30 ==============================
#
# [RUN 5 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 576ms/step
# Classification Report (MobileNet-Mel, Run 5):
#                precision    recall  f1-score   support
#
#       Cendet       0.90      0.95      0.92        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 5 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 108: early stopping
# Restoring model weights from the end of the best epoch: 98.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 604ms/step
# Classification Report (MobileNet-MFCC, Run 5):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      0.85      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.88      0.93      0.90        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.95       112
#    macro avg       0.95      0.93      0.94       112
# weighted avg       0.95      0.95      0.95       112
#
#
# ============================== RUN 6/30 ==============================
#
# [RUN 6 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 590ms/step
# Classification Report (MobileNet-Mel, Run 6):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.98       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# [RUN 6 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 593ms/step
# Classification Report (MobileNet-MFCC, Run 6):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.84      0.89        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.93      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.86      1.00      0.93        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# ============================== RUN 7/30 ==============================
#
# [RUN 7 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 597ms/step
# Classification Report (MobileNet-Mel, Run 7):
#                precision    recall  f1-score   support
#
#       Cendet       0.90      0.95      0.92        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.95       112
#    macro avg       0.95      0.94      0.94       112
# weighted avg       0.95      0.95      0.95       112
#
#
# [RUN 7 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 579ms/step
# Classification Report (MobileNet-MFCC, Run 7):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       0.94      0.94      0.94        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# ============================== RUN 8/30 ==============================
#
# [RUN 8 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 582ms/step
# Classification Report (MobileNet-Mel, Run 8):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.98       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# [RUN 8 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 584ms/step
# Classification Report (MobileNet-MFCC, Run 8):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.90      0.95      0.92        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# ============================== RUN 9/30 ==============================
#
# [RUN 9 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 603ms/step
# Classification Report (MobileNet-Mel, Run 9):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 9 - Model 2] Transfer Learning MobileNet (MFCC)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 595ms/step
# Classification Report (MobileNet-MFCC, Run 9):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.98       112
#    macro avg       0.98      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# ============================== RUN 10/30 ==============================
#
# [RUN 10 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 599ms/step
# Classification Report (MobileNet-Mel, Run 10):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       0.94      1.00      0.97        16
#      Tekukur       1.00      0.80      0.89        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.95      0.95      0.95       112
# weighted avg       0.96      0.96      0.95       112
#
#
# [RUN 10 - Model 2] Transfer Learning MobileNet (MFCC)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 586ms/step
# Classification Report (MobileNet-MFCC, Run 10):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.84      0.89        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       0.94      1.00      0.97        16
#      Tekukur       0.92      0.80      0.86        15
#     Trucukan       0.86      1.00      0.93        19
#
#     accuracy                           0.94       112
#    macro avg       0.94      0.93      0.93       112
# weighted avg       0.94      0.94      0.94       112
#
#
# ============================== RUN 11/30 ==============================
#
# [RUN 11 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 70.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 594ms/step
# Classification Report (MobileNet-Mel, Run 11):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 11 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step
# Classification Report (MobileNet-MFCC, Run 11):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.79      0.88        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.85      0.97      0.91        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.95       112
#    macro avg       0.97      0.95      0.96       112
# weighted avg       0.95      0.95      0.95       112
#
#
# ============================== RUN 12/30 ==============================
#
# [RUN 12 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 580ms/step
# Classification Report (MobileNet-Mel, Run 12):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.91      1.00      0.95        30
#     Perkutut       0.93      0.81      0.87        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.97       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 12 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 587ms/step
# Classification Report (MobileNet-MFCC, Run 12):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.93      0.87      0.90        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 13/30 ==============================
#
# [RUN 13 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 573ms/step
# Classification Report (MobileNet-Mel, Run 13):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 13 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 594ms/step
# Classification Report (MobileNet-MFCC, Run 13):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.84      0.91        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.88      1.00      0.94        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.95       112
#    macro avg       0.95      0.95      0.95       112
# weighted avg       0.95      0.95      0.95       112
#
#
# ============================== RUN 14/30 ==============================
#
# [RUN 14 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 581ms/step
# Classification Report (MobileNet-Mel, Run 14):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.95      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# [RUN 14 - Model 2] Transfer Learning MobileNet (MFCC)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 584ms/step
# Classification Report (MobileNet-MFCC, Run 14):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       0.79      1.00      0.88        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.97      0.96      0.97       112
#
#
# ============================== RUN 15/30 ==============================
#
# [RUN 15 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 624ms/step
# Classification Report (MobileNet-Mel, Run 15):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.94      0.89      0.92        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 15 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 84.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 603ms/step
# Classification Report (MobileNet-MFCC, Run 15):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 16/30 ==============================
#
# [RUN 16 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 65: early stopping
# Restoring model weights from the end of the best epoch: 55.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 581ms/step
# Classification Report (MobileNet-Mel, Run 16):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.95      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 16 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 39.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 585ms/step
# Classification Report (MobileNet-MFCC, Run 16):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.79      0.86        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.88      1.00      0.94        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.88      1.00      0.94        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.94       112
#    macro avg       0.95      0.93      0.94       112
# weighted avg       0.94      0.94      0.94       112
#
#
# ============================== RUN 17/30 ==============================
#
# [RUN 17 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 98: early stopping
# Restoring model weights from the end of the best epoch: 88.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 583ms/step
# Classification Report (MobileNet-Mel, Run 17):
#                precision    recall  f1-score   support
#
#       Cendet       0.90      0.95      0.92        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 17 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 594ms/step
# Classification Report (MobileNet-MFCC, Run 17):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.98       112
#    macro avg       0.99      0.98      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# ============================== RUN 18/30 ==============================
#
# [RUN 18 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 585ms/step
# Classification Report (MobileNet-Mel, Run 18):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 18 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 593ms/step
# Classification Report (MobileNet-MFCC, Run 18):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.99       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.99      0.99      0.99       112
#
#
# ============================== RUN 19/30 ==============================
#
# [RUN 19 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 576ms/step
# Classification Report (MobileNet-Mel, Run 19):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.98       112
#    macro avg       0.98      0.99      0.98       112
# weighted avg       0.98      0.98      0.98       112
#
#
# [RUN 19 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 584ms/step
# Classification Report (MobileNet-MFCC, Run 19):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       1.00      0.93      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.98      0.97       112
# weighted avg       0.98      0.97      0.97       112
#
#
# ============================== RUN 20/30 ==============================
#
# [RUN 20 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 587ms/step
# Classification Report (MobileNet-Mel, Run 20):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      0.95      0.95        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 20 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 36.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 574ms/step
# Classification Report (MobileNet-MFCC, Run 20):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.92      0.85      0.88        13
#     Kutilang       1.00      0.97      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
#
# ============================== RUN 21/30 ==============================
#
# [RUN 21 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 572ms/step
# Classification Report (MobileNet-Mel, Run 21):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      0.95      0.95        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 21 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 596ms/step
# Classification Report (MobileNet-MFCC, Run 21):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 22/30 ==============================
#
# [RUN 22 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 580ms/step
# Classification Report (MobileNet-Mel, Run 22):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.91      1.00      0.95        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.87      0.93        15
#     Trucukan       0.94      0.89      0.92        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.95      0.96       112
# weighted avg       0.96      0.96      0.95       112
#
#
# [RUN 22 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 612ms/step
# Classification Report (MobileNet-MFCC, Run 22):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.90      0.95      0.92        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 23/30 ==============================
#
# [RUN 23 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 594ms/step
# Classification Report (MobileNet-Mel, Run 23):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.81      1.00      0.90        13
#     Kutilang       0.91      0.97      0.94        30
#     Perkutut       1.00      0.88      0.93        16
#      Tekukur       1.00      0.80      0.89        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.93       112
#    macro avg       0.94      0.92      0.92       112
# weighted avg       0.94      0.93      0.93       112
#
#
# [RUN 23 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 600ms/step
# Classification Report (MobileNet-MFCC, Run 23):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.89      0.94        19
#       Gereja       0.76      1.00      0.87        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.80      0.89        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.94       112
#    macro avg       0.94      0.93      0.93       112
# weighted avg       0.95      0.94      0.94       112
#
#
# ============================== RUN 24/30 ==============================
#
# [RUN 24 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 577ms/step
# Classification Report (MobileNet-Mel, Run 24):
#                precision    recall  f1-score   support
#
#       Cendet       0.90      1.00      0.95        19
#       Gereja       1.00      0.92      0.96        13
#     Kutilang       0.97      0.93      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 24 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 593ms/step
# Classification Report (MobileNet-MFCC, Run 24):
#                precision    recall  f1-score   support
#
#       Cendet       0.95      1.00      0.97        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       0.94      0.97      0.95        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# ============================== RUN 25/30 ==============================
#
# [RUN 25 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 112: early stopping
# Restoring model weights from the end of the best epoch: 102.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 586ms/step
# Classification Report (MobileNet-Mel, Run 25):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       0.92      0.92      0.92        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 25 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 51.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 586ms/step
# Classification Report (MobileNet-MFCC, Run 25):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.84      0.89        19
#       Gereja       1.00      0.85      0.92        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.83      1.00      0.91        15
#     Trucukan       0.90      1.00      0.95        19
#
#     accuracy                           0.95       112
#    macro avg       0.95      0.94      0.94       112
# weighted avg       0.95      0.95      0.95       112
#
#
# ============================== RUN 26/30 ==============================
#
# [RUN 26 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 107: early stopping
# Restoring model weights from the end of the best epoch: 97.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 590ms/step
# Classification Report (MobileNet-Mel, Run 26):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.98       112
#    macro avg       0.99      0.99      0.99       112
# weighted avg       0.98      0.98      0.98       112
#
#
# [RUN 26 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 583ms/step
# Classification Report (MobileNet-MFCC, Run 26):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      0.97      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.97      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 27/30 ==============================
#
# [RUN 27 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 45.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 580ms/step
# Classification Report (MobileNet-Mel, Run 27):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.81      0.90        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# [RUN 27 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 44.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 590ms/step
# Classification Report (MobileNet-MFCC, Run 27):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       0.93      0.88      0.90        16
#      Tekukur       0.94      1.00      0.97        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# ============================== RUN 28/30 ==============================
#
# [RUN 28 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 574ms/step
# Classification Report (MobileNet-Mel, Run 28):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# [RUN 28 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 594ms/step
# Classification Report (MobileNet-MFCC, Run 28):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      1.00      1.00        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       1.00      1.00      1.00        30
#     Perkutut       1.00      1.00      1.00        16
#      Tekukur       1.00      1.00      1.00        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           1.00       112
#    macro avg       1.00      1.00      1.00       112
# weighted avg       1.00      1.00      1.00       112
#
#
# ============================== RUN 29/30 ==============================
#
# [RUN 29 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 569ms/step
# Classification Report (MobileNet-Mel, Run 29):
#                precision    recall  f1-score   support
#
#       Cendet       0.94      0.89      0.92        19
#       Gereja       0.93      1.00      0.96        13
#     Kutilang       0.94      1.00      0.97        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.93      0.97        15
#     Trucukan       1.00      1.00      1.00        19
#
#     accuracy                           0.96       112
#    macro avg       0.97      0.96      0.96       112
# weighted avg       0.97      0.96      0.96       112
#
#
# [RUN 29 - Model 2] Transfer Learning MobileNet (MFCC)
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 594ms/step
# Classification Report (MobileNet-MFCC, Run 29):
#                precision    recall  f1-score   support
#
#       Cendet       1.00      0.95      0.97        19
#       Gereja       1.00      1.00      1.00        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       0.93      0.93      0.93        15
#     Trucukan       0.95      1.00      0.97        19
#
#     accuracy                           0.97       112
#    macro avg       0.98      0.97      0.97       112
# weighted avg       0.97      0.97      0.97       112
#
#
# ============================== RUN 30/30 ==============================
#
# [RUN 30 - Model 1] Transfer Learning MobileNet (Mel-spectrogram)
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Restoring model weights from the end of the best epoch: 120.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 601ms/step
# Classification Report (MobileNet-Mel, Run 30):
#                precision    recall  f1-score   support
#
#       Cendet       0.90      1.00      0.95        19
#       Gereja       0.87      1.00      0.93        13
#     Kutilang       0.97      1.00      0.98        30
#     Perkutut       1.00      0.94      0.97        16
#      Tekukur       1.00      0.80      0.89        15
#     Trucukan       1.00      0.95      0.97        19
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.95      0.95       112
# weighted avg       0.96      0.96      0.95       112
#
#
# [RUN 30 - Model 2] Transfer Learning MobileNet (MFCC)
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
